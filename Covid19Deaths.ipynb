# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# <h2>Importing Data Sets</h2>

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_deaths_dataset.csv")
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...       36
# ...

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# <h2>Removing Unnecessary Columns</h2>

# %%
corona_dataset_csv.drop(["Lat", "Long"],axis=1,inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# <h2>Aggregating Rows</h2>

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        0        0
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %% [markdown]
# <h2>Visualising Deaths Among Various Countries <\h2>

# %%
corona_dataset_aggregated.loc["China"].plot()

# %% [markdown]
# <h2>Calculating Good Measure</h2>

# %%
corona_dataset_aggregated.loc["China"].diff().plot()

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 1290.0

# %%
countries = list(corona_dataset_aggregated.index)
maximum_death_rate=[]
for c in countries:
    maximum_death_rate.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["maximum_death_rate"] = maximum_death_rate

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %% [markdown]
# <h2>Creating a new data frame with the requiredd column only<\h2>

# %%
corona_data= pd.DataFrame(corona_dataset_aggregated["maximum_death_rate"])

# %%
corona_data.head()
# Out:
#                 maximum_death_rate
# Country/Region
# Afghanistan                    7.0
# Albania                        4.0
# Algeria                       30.0
# Andorra                        4.0
# Angola                         2.0

# %% [markdown]
# <h2>Preparing Happiness Data Set<\h2>

# %%
happiness_report_csv = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happiness_report_csv.drop(["Overall rank","Score", "Generosity", "Perceptions of corruption"],axis=1,inplace=True)

# %%
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report_csv.set_index("Country or region", inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# <h2>Joining both data sets<\h2>

# %%
data = corona_data.join(happiness_report_csv, how="inner")
data.head()
# Out:
#              maximum_death_rate  GDP per capita  Social support  \
# Afghanistan                 7.0           0.350           0.517
# Albania                     4.0           0.947           0.848
# Algeria                    30.0           1.002           1.160
# Argentina                  13.0           1.092           1.432
# Armenia                     3.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# <h2>Corealation Matrix<\h2>

# %%
data.corr()
# Out:
#                               maximum_death_rate  GDP per capita  \
# maximum_death_rate                      1.000000        0.259893
# GDP per capita                          0.259893        1.000000
# Social support                          0.204148        0.759468
# Healthy life expectancy                 0.309666        0.863062
# Freedom to make life choices            0.080166        0.394603
#
#                               Social support  Healthy life expectancy  \
# maximum_death_rate                  0.204148                 0.309666
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# maximum_death_rate                                0.080166
# ...

# %% [markdown]
# <h2>Visualising Result<\h2>

# %%
x=data["GDP per capita"]
y= data["maximum_death_rate"]
sns.scatterplot(x,y)

# %%
sns.regplot(x,y)

# %%
x=data["Social support"]
y= data["maximum_death_rate"]
sns.scatterplot(x,np.log(y))
# Out:
# C:\Users\thisi\anaconda3\lib\site-packages\pandas\core\series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.regplot(x,y)

# %%
x=data["Healthy life expectancy"]
y= data["maximum_death_rate"]
sns.scatterplot(x,y)

# %%
sns.regplot(x,y)

# %%
x=data["Freedom to make life choices"]
y= data["maximum_death_rate"]
sns.scatterplot(x,y)

# %%
sns.regplot(x,y)
